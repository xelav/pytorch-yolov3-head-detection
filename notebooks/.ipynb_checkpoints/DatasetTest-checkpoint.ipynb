# %%
import sys
sys.path.append('..')

from train import prepare_dataloaders
import json
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import cv2
import numpy as np

# %load_ext autoreload
# %autoreload 2

# %%
config_path = '../config/runs/config-local.json'
with open(config_path) as config_buffer:
    config = json.loads(config_buffer.read())

# %%
train_loader = prepare_dataloaders(config)
# Out:
# Size of the split: 3405
# Size of the split: 216719

# %% [markdown]
# # Train Dataloader

# %%
it = iter(train_loader)

# %%
it = iter(val_loader)

# %%
image_batch, bboxes = next(it)
image_batch.shape, bboxes.shape
# Out:
# (torch.Size([16, 3, 416, 416]), torch.Size([26, 6]))

# %%
def show_images(images, targets, cols = 1, titles = None):
    """Display a list of images in a single figure with matplotlib.
    
    Parameters
    ---------
    images: List of np.arrays compatible with plt.imshow.
    
    cols (Default = 1): Number of columns in figure (number of rows is 
                        set to np.ceil(n_images/float(cols))).
    
    titles: List of titles corresponding to each image. Must have
            the same length as titles.
            
    https://gist.github.com/soply/f3eec2e79c165e39c9d540e916142ae1
    """
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = [f'Image {i}' for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(np.ceil(n_images/float(cols)), cols, n + 1)
        
        if image.ndim == 2:
            plt.gray()
            
        img_w, img_h, _ = image.shape
            
        image_bboxes = bboxes[bboxes[:,0] == n]
        for _, _, xc, yc, w, h in image_bboxes:
            # print("\t+ Label: %s, Conf: %.5f" % (classes[int(cls_pred)], cls_conf.item()))

            x1 = (xc - w*0.5) * img_w
            y1 = (yc - h*0.5) * img_h
            w_box = w * img_w
            h_box = h * img_h

            color = (1,0,1)
            # Create a Rectangle patch
            patch = patches.Rectangle((x1, y1), w_box, h_box, linewidth=2, edgecolor=color, facecolor="none")
            # Add the bbox to the plot
            a.add_patch(patch)
            
        plt.imshow(image)
        a.set_title(title)
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.show()

# %%
show_images(image_batch.int().numpy().transpose(0,2,3,1), bboxes, cols=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-7d93a8cf08d2> in <module>
# ----> 1 show_images(image_batch.int().numpy().transpose(0,2,3,1), bboxes, cols=1)
#
# <ipython-input-8-bc01f8a61941> in show_images(images, targets, cols, titles)
#      24             plt.gray()
#      25
# ---> 26         img_w, img_h, _ = img.shape
#      27
#      28         image_bboxes = bboxes[bboxes[:,0] == n]
#
# NameError: name 'img' is not defined

# %%
_, _, xc, yc, w, h = bbox

# %%
for i, img in enumerate(image_batch):

    plt.rcParams['figure.figsize'] = [7, 7]

    plt.figure()
    fig, ax = plt.subplots(1)
    img = img.int().numpy().transpose(1,2,0)
    ax.imshow(img)

    img_w, img_h, _ = img.shape
    print(img_w, img_h)
    
    image_bboxes = bboxes[bboxes[:,0] == i]
    for _, _, xc, yc, w, h in image_bboxes:
        # print("\t+ Label: %s, Conf: %.5f" % (classes[int(cls_pred)], cls_conf.item()))

        x1 = (xc - w*1.5) * img_w
        y1 = (yc + h*0.5) * img_h
        w_box = w * img_w
        h_box = h * img_h

        color = (1,0,1)
        # Create a Rectangle patch
        patch = patches.Rectangle((x1, y1), w_box, h_box, linewidth=2, edgecolor=color, facecolor="none")
        # Add the bbox to the plot
        ax.add_patch(patch)
# Out:
# 384 384
# 384 384
